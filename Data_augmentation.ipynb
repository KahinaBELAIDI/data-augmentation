# %% [markdown]
# # Image Augmentation with Keras
#
# ![Texte alternatif…](https://imgur.com/HJlIjG7.png)

# %%
import numpy as np
import tensorflow as tf

from matplotlib import pyplot as plt

# %%
image_path = 'dog.jpg'

plt.imshow(plt.imread(image_path))

# %%
img = plt.imread(image_path)

# %% [markdown]
# # Rotation

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=40
)

# %%
x = next(generator.flow(np.expand_dims(img, axis=0), batch_size=1))
plt.imshow(x[0,:].astype('uint8'))

# %% [markdown]
# # Width and Height Shifts

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    
    height_shift_range=-0.2
)

# %%
y = next(generator.flow(np.expand_dims(img, axis=0), batch_size=1))
plt.imshow(y[0].astype('uint8'))

# %% [markdown]
# # Brighteness

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    brightness_range=(0., 2.)
)

x = next(generator.flow(np.expand_dims(img, axis=0), batch_size=1))
plt.imshow(x[0].astype('uint8'))

# %% [markdown]
# # Zoom

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    zoom_range=0.5

)

x= next(generator.flow(np.expand_dims(img, axis=0), batch_size=1))
plt.imshow(x[0,:].astype('uint8'))

# %% [markdown]
# # Flip

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip=True
)

x = next(generator.flow(np.expand_dims(img, axis=0), batch_size=1))
plt.imshow(x[0].astype('uint8'))

# %% [markdown]
# # Rescale

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)
x = next(generator.flow(np.expand_dims(img, axis=0), batch_size=1))
plt.imshow(x[0])

# %%
x[0].mean(), x[0].std()
# Out:
# (0.5487161, 0.17243008)
